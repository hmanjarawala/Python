# %%
import lazypredict
from lazypredict import LazyRegressor
# Out:
# C:\Users\himanshu.manjarawala\AppData\Local\Continuum\anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# C:\Users\himanshu.manjarawala\AppData\Local\Continuum\anaconda3\lib\site-packages\distributed\config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
from sklearn.datasets import load_boston
from sklearn.utils import shuffle
import numpy as np

# %%
boston = load_boston()

# %%
X, y = shuffle(boston.data, boston.target, random_state=13)

# %%
X = X.astype(np.float32)
offset = int(X.shape[0] * 0.9)
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# %%
reg = LazyRegressor(verbose=0,ignore_warnings=False, custom_metric=None )

# %%
models,predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 36/36 [00:01<00:00, 19.63it/s]
#                              R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor               0.90  2.38        0.04
# SVR                               0.88  2.62        0.02
# RandomForestRegressor             0.86  2.76        0.05
# NuSVR                             0.86  2.76        0.02
# XGBRegressor                      0.86  2.79        0.13
# GradientBoostingRegressor         0.86  2.84        0.07
# BaggingRegressor                  0.85  2.92        0.04
# AdaBoostRegressor                 0.83  3.04        0.13
# LGBMRegressor                     0.83  3.11        0.11
# KNeighborsRegressor               0.83  3.12        0.01
# ExtraTreeRegressor                0.76  3.66        0.02
# DecisionTreeRegressor             0.75  3.75        0.01
# MLPRegressor                      0.74  3.80        0.60
# HuberRegressor                    0.74  3.84        0.02
# LinearSVR                         0.72  3.96        0.01
# RidgeCV                           0.72  3.97        0.01
# BayesianRidge                     0.72  3.97        0.02
# Ridge                             0.72  3.97        0.01
# TransformedTargetRegressor        0.72  3.97        0.01
# LinearRegression                  0.72  3.97        0.01
# LassoCV                           0.72  3.98        0.07
# ElasticNetCV                      0.72  3.98        0.05
# LassoLarsCV                       0.72  3.98        0.04
# LassoLarsIC                       0.72  3.98        0.01
# LarsCV                            0.72  3.99        0.03
# Lars                              0.72  3.99        0.01
# SGDRegressor                      0.69  4.16        0.01
# ElasticNet                        0.69  4.16        0.01
# PassiveAggressiveRegressor        0.67  4.31        0.01
# Lasso                             0.66  4.35        0.01
# RANSACRegressor                   0.65  4.41        0.09
# OrthogonalMatchingPursuitCV       0.59  4.78        0.01
# GaussianProcessRegressor          0.43  5.65        0.04
# OrthogonalMatchingPursuit         0.38  5.89        0.01
# LassoLars                        -0.02  7.56        0.01
# KernelRidge                      -8.25 22.74        0.02
